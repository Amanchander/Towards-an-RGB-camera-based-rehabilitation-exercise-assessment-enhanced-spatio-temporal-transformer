# %%
pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences

# dimension of data sequences
n_dim = 88 # dimension after segmenting the data into body parts
batch_size = 2

# %%
import joblib

exercise = 'E1'
split_no = '2'

split_data_path = '/content/' + exercise + '_split_' + split_no + '.pkl'
split_data = joblib.load(split_data_path)

X_train = split_data['train']['data']
y_train = split_data['train']['labels']

X_test = split_data['test']['data']
y_test = split_data['test']['labels']

train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

test_x = X_test
test_y = y_test

# %%
import numpy as np

# Replace NaN values with mean in training data
nan_mask_train_X = np.isnan(X_train)
mean_values_train_X = np.nanmean(X_train)
X_train[nan_mask_train_X] = mean_values_train_X

nan_mask_train_y = np.isnan(y_train)
mean_values_train_y = np.nanmean(y_train)
y_train[nan_mask_train_y] = mean_values_train_y

# Replace NaN values with mean in testing data
nan_mask_test_X = np.isnan(X_test)
mean_values_test_X = np.nanmean(X_test)
X_test[nan_mask_test_X] = mean_values_test_X

nan_mask_test_y = np.isnan(y_test)
mean_values_test_y = np.nanmean(y_test)
y_test[nan_mask_test_y] = mean_values_test_y


print("The X_train size is ", X_train.shape)
print("The y_train size is ", y_train.shape)
print("The X_test size is ", X_test.shape)
print("The y_test size is ", y_test.shape)



def makeDataDivisibleBy8(myData):
    newData = []
    for file in myData:
      file_length = file.shape[0]
      new_length = file.shape[0]

      while (new_length % 8) != 0:
        new_length += 1
        print("New length is ", new_length)

      print("The desired length is ", new_length)

      rows_to_append = new_length - file_length

      zero_rows = np.zeros((rows_to_append, file.shape[1]))
      file = np.vstack([file, zero_rows])
      newData.append(file)

    print("The size after zero stacking is ", newData[0].shape)

    return np.array(newData)


train_x = makeDataDivisibleBy8(train_x)
valid_x = makeDataDivisibleBy8(valid_x)
test_x  = makeDataDivisibleBy8(test_x)

timesteps = train_x.shape[1]
# Out:
# The X_train size is  (120, 180, 132)
# The y_train size is  (120,)
# The X_test size is  (40, 180, 132)
# The y_test size is  (40,)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
testx = test_x

trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)

trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)

trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)


trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]

trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]

trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
# Code to re-order the 132 dimensional skeleton data from the mediapipe sekeleton into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],16))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],16))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],16))

    X_trunk =  np.concatenate((x[:,:,44:52], x[:,:,92:100]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,52:56], x[:,:,60:64], x[:,:,68:72], x[:,:,76:80], x[:,:,84:88]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,56:60], x[:,:,64:68], x[:,:,72:76], x[:,:,80:84], x[:,:,88:92]), axis = 2)
    X_left_leg = np.concatenate((x[:,:,100:104], x[:,:,108:112], x[:,:,116:120], x[:,:,124:128]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,104:108], x[:,:,112:116], x[:,:,120:124], x[:,:,128:132]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented


# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
test_x =  reorder_data(test_x)

trainx_2 =  reorder_data(trainx_2)
validx_2 =  reorder_data(validx_2)
testx_2 = reorder_data(testx_2)

trainx_4 =  reorder_data(trainx_4)
validx_4 =  reorder_data(validx_4)
testx_4 = reorder_data(testx_4)

trainx_8 =  reorder_data(trainx_8)
validx_8 =  reorder_data(validx_8)
testx_8 = reorder_data(testx_8)

# %%
print(trainx.shape)
print(validx.shape)
print(test_x.shape)

print(trainx_2.shape)
print(validx_2.shape)
print(testx_2.shape)

print(trainx_4.shape)
print(validx_4.shape)
print(testx_4.shape)

print(trainx_8.shape)
print(validx_8.shape)
print(testx_8.shape)
# Out:
# (72, 184, 88)
# (48, 184, 88)
# (40, 184, 88)
# (72, 92, 88)
# (48, 92, 88)
# (40, 92, 88)
# (72, 46, 88)
# (48, 46, 88)
# (40, 46, 88)
# (72, 23, 88)
# (48, 23, 88)
# (40, 23, 88)

# %%
n_dim = 88 # dimension after segmenting the data into body parts
n_dim1 = 16 # trunk dimension
n_dim2 = 20 # arms dimension
n_dim3 = 16 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 17:36])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 37:56])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 57:72])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 73:88])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 17:36])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 37:56])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 57:72])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 73:88])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 17:36])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 37:56])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 57:72])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 73:88])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 17:36])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 37:56])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 57:72])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 73:88])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 16)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 16)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 16)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 16)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 184, 88)]            0         []
#
#  half_scale (InputLayer)     [(None, 92, 88)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 46, 88)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 23, 88)]             0         []
#
#  lambda_40 (Lambda)          (None, 184, 16)              0         ['full_scale[0][0]']
#
#  lambda_45 (Lambda)          (None, 92, 16)               0         ['half_scale[0][0]']
#
#  lambda_50 (Lambda)          (None, 46, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_55 (Lambda)          (None, 23, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_41 (Lambda)          (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_46 (Lambda)          (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_51 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_56 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_42 (Lambda)          (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_47 (Lambda)          (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_52 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_57 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_43 (Lambda)          (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_48 (Lambda)          (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_53 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_58 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  lambda_44 (Lambda)          (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_49 (Lambda)          (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_54 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_59 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  tcn_46 (TCN)                (None, 184, 12)              5676      ['lambda_40[0][0]']
#
#  tcn_47 (TCN)                (None, 92, 12)               5676      ['lambda_45[0][0]']
#
#  tcn_48 (TCN)                (None, 46, 12)               5676      ['lambda_50[0][0]']
#
#  tcn_49 (TCN)                (None, 23, 12)               5676      ['lambda_55[0][0]']
#
#  tcn_50 (TCN)                (None, 184, 12)              5820      ['lambda_41[0][0]']
#
#  tcn_51 (TCN)                (None, 92, 12)               5820      ['lambda_46[0][0]']
#
#  tcn_52 (TCN)                (None, 46, 12)               5820      ['lambda_51[0][0]']
#
#  tcn_53 (TCN)                (None, 23, 12)               5820      ['lambda_56[0][0]']
#
#  tcn_54 (TCN)                (None, 184, 12)              5820      ['lambda_42[0][0]']
#
#  tcn_55 (TCN)                (None, 92, 12)               5820      ['lambda_47[0][0]']
#
#  tcn_56 (TCN)                (None, 46, 12)               5820      ['lambda_52[0][0]']
#
#  tcn_57 (TCN)                (None, 23, 12)               5820      ['lambda_57[0][0]']
#
#  tcn_58 (TCN)                (None, 184, 12)              5628      ['lambda_43[0][0]']
#
#  tcn_59 (TCN)                (None, 92, 12)               5628      ['lambda_48[0][0]']
#
#  tcn_60 (TCN)                (None, 46, 12)               5628      ['lambda_53[0][0]']
#
#  tcn_61 (TCN)                (None, 23, 12)               5628      ['lambda_58[0][0]']
#
#  tcn_62 (TCN)                (None, 184, 12)              5628      ['lambda_44[0][0]']
#
#  tcn_63 (TCN)                (None, 92, 12)               5628      ['lambda_49[0][0]']
#
#  tcn_64 (TCN)                (None, 46, 12)               5628      ['lambda_54[0][0]']
#
#  tcn_65 (TCN)                (None, 23, 12)               5628      ['lambda_59[0][0]']
#
#  concatenate_12 (Concatenat  (None, 345, 12)              0         ['tcn_46[0][0]',
#  e)                                                                  'tcn_47[0][0]',
#                                                                      'tcn_48[0][0]',
#                                                                      'tcn_49[0][0]']
#
#  concatenate_13 (Concatenat  (None, 345, 12)              0         ['tcn_50[0][0]',
#  e)                                                                  'tcn_51[0][0]',
#                                                                      'tcn_52[0][0]',
#                                                                      'tcn_53[0][0]']
#
#  concatenate_14 (Concatenat  (None, 345, 12)              0         ['tcn_54[0][0]',
#  e)                                                                  'tcn_55[0][0]',
#                                                                      'tcn_56[0][0]',
#                                                                      'tcn_57[0][0]']
#
#  concatenate_15 (Concatenat  (None, 345, 12)              0         ['tcn_58[0][0]',
#  e)                                                                  'tcn_59[0][0]',
#                                                                      'tcn_60[0][0]',
#                                                                      'tcn_61[0][0]']
#
#  concatenate_16 (Concatenat  (None, 345, 12)              0         ['tcn_62[0][0]',
#  e)                                                                  'tcn_63[0][0]',
#                                                                      'tcn_64[0][0]',
#                                                                      'tcn_65[0][0]']
#
#  concatenate_17 (Concatenat  (None, 345, 60)              0         ['concatenate_12[0][0]',
#  e)                                                                  'concatenate_13[0][0]',
#                                                                      'concatenate_14[0][0]',
#                                                                      'concatenate_15[0][0]',
#                                                                      'concatenate_16[0][0]']
#
#  tcn_66 (TCN)                (None, 345, 12)              6012      ['concatenate_17[0][0]']
#
#  tcn_67 (TCN)                (None, 345, 8)               1176      ['tcn_66[0][0]']
#
#  tcn_68 (TCN)                (None, 6)                    546       ['tcn_67[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    7         ['tcn_68[0][0]']
#
# ==================================================================================================
# Total params: 122029 (476.68 KB)
# Trainable params: 121933 (476.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 11/11 [==============================] - ETA: 0s - loss: 1.7019
# Epoch 1: val_loss improved from inf to 3.02318, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 11/11 [==============================] - 338s 3s/step - loss: 1.7019 - val_loss: 3.0232
# Epoch 2/400
# 11/11 [==============================] - ETA: 0s - loss: 0.3105
# Epoch 2: val_loss improved from 3.02318 to 0.42201, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 509ms/step - loss: 0.3105 - val_loss: 0.4220
# Epoch 3/400
# 11/11 [==============================] - ETA: 0s - loss: 0.2208
# Epoch 3: val_loss improved from 0.42201 to 0.12579, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 565ms/step - loss: 0.2208 - val_loss: 0.1258
# Epoch 4/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1395
# Epoch 4: val_loss improved from 0.12579 to 0.02218, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 564ms/step - loss: 0.1395 - val_loss: 0.0222
# Epoch 5/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1546
# Epoch 5: val_loss improved from 0.02218 to 0.02181, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 492ms/step - loss: 0.1546 - val_loss: 0.0218
# Epoch 6/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1381
# Epoch 6: val_loss did not improve from 0.02181
# 11/11 [==============================] - 4s 337ms/step - loss: 0.1381 - val_loss: 0.0397
# Epoch 7/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1412
# Epoch 7: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 189ms/step - loss: 0.1412 - val_loss: 0.0666
# Epoch 8/400
# 11/11 [==============================] - ETA: 0s - loss: 0.2214
# Epoch 8: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 201ms/step - loss: 0.2214 - val_loss: 0.0736
# Epoch 9/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1493
# Epoch 9: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 195ms/step - loss: 0.1493 - val_loss: 0.0840
# Epoch 10/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1260
# Epoch 10: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 232ms/step - loss: 0.1260 - val_loss: 0.0745
# Epoch 11/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1450
# Epoch 11: val_loss did not improve from 0.02181
# 11/11 [==============================] - 3s 293ms/step - loss: 0.1450 - val_loss: 0.0785
# Epoch 12/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1410
# Epoch 12: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 201ms/step - loss: 0.1410 - val_loss: 0.0679
# Epoch 13/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 13: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 227ms/step - loss: 0.0675 - val_loss: 0.0551
# Epoch 14/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1203
# Epoch 14: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 205ms/step - loss: 0.1203 - val_loss: 0.0399
# Epoch 15/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1292
# Epoch 15: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 201ms/step - loss: 0.1292 - val_loss: 0.0368
# Epoch 16/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0553
# Epoch 16: val_loss did not improve from 0.02181
# 11/11 [==============================] - 3s 314ms/step - loss: 0.0553 - val_loss: 0.0317
# Epoch 17/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 17: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0559 - val_loss: 0.0448
# Epoch 18/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1164
# Epoch 18: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 191ms/step - loss: 0.1164 - val_loss: 0.0373
# Epoch 19/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0634
# Epoch 19: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0634 - val_loss: 0.0419
# Epoch 20/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0788
# Epoch 20: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0788 - val_loss: 0.0431
# Epoch 21/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 21: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 234ms/step - loss: 0.0790 - val_loss: 0.0373
# Epoch 22/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0347
# Epoch 22: val_loss did not improve from 0.02181
# 11/11 [==============================] - 3s 299ms/step - loss: 0.0347 - val_loss: 0.0343
# Epoch 23/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 23: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0642 - val_loss: 0.0296
# Epoch 24/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0901
# Epoch 24: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0901 - val_loss: 0.0251
# Epoch 25/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1115
# Epoch 25: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 192ms/step - loss: 0.1115 - val_loss: 0.0220
# Epoch 26/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0649
# Epoch 26: val_loss did not improve from 0.02181
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0649 - val_loss: 0.0221
# Epoch 27/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0778
# Epoch 27: val_loss improved from 0.02181 to 0.01589, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 598ms/step - loss: 0.0778 - val_loss: 0.0159
# Epoch 28/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 28: val_loss improved from 0.01589 to 0.00964, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0665 - val_loss: 0.0096
# Epoch 29/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 29: val_loss did not improve from 0.00964
# 11/11 [==============================] - 2s 223ms/step - loss: 0.0285 - val_loss: 0.0120
# Epoch 30/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 30: val_loss did not improve from 0.00964
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0520 - val_loss: 0.0161
# Epoch 31/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0603
# Epoch 31: val_loss did not improve from 0.00964
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0603 - val_loss: 0.0181
# Epoch 32/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0617
# Epoch 32: val_loss did not improve from 0.00964
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0617 - val_loss: 0.0139
# Epoch 33/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0748
# Epoch 33: val_loss did not improve from 0.00964
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0748 - val_loss: 0.0124
# Epoch 34/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 34: val_loss did not improve from 0.00964
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0373 - val_loss: 0.0112
# Epoch 35/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 35: val_loss improved from 0.00964 to 0.00911, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 581ms/step - loss: 0.0475 - val_loss: 0.0091
# Epoch 36/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 36: val_loss improved from 0.00911 to 0.00706, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0628 - val_loss: 0.0071
# Epoch 37/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 37: val_loss improved from 0.00706 to 0.00665, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 540ms/step - loss: 0.0475 - val_loss: 0.0067
# Epoch 38/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 38: val_loss improved from 0.00665 to 0.00566, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 506ms/step - loss: 0.0383 - val_loss: 0.0057
# Epoch 39/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 39: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0369 - val_loss: 0.0064
# Epoch 40/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 40: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 230ms/step - loss: 0.0266 - val_loss: 0.0064
# Epoch 41/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0519
# Epoch 41: val_loss did not improve from 0.00566
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0519 - val_loss: 0.0065
# Epoch 42/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0470
# Epoch 42: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0470 - val_loss: 0.0071
# Epoch 43/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0372
# Epoch 43: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0372 - val_loss: 0.0122
# Epoch 44/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 44: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0267 - val_loss: 0.0120
# Epoch 45/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 45: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0292 - val_loss: 0.0114
# Epoch 46/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0418
# Epoch 46: val_loss did not improve from 0.00566
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0418 - val_loss: 0.0092
# Epoch 47/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 47: val_loss did not improve from 0.00566
# 11/11 [==============================] - 3s 287ms/step - loss: 0.0161 - val_loss: 0.0094
# Epoch 48/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 48: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0210 - val_loss: 0.0092
# Epoch 49/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 49: val_loss did not improve from 0.00566
# 11/11 [==============================] - 2s 216ms/step - loss: 0.0148 - val_loss: 0.0072
# Epoch 50/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 50: val_loss improved from 0.00566 to 0.00516, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 515ms/step - loss: 0.0277 - val_loss: 0.0052
# Epoch 51/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 51: val_loss did not improve from 0.00516
# 11/11 [==============================] - 3s 252ms/step - loss: 0.0267 - val_loss: 0.0066
# Epoch 52/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 52: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0193 - val_loss: 0.0097
# Epoch 53/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 53: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0249 - val_loss: 0.0089
# Epoch 54/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 54: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0206 - val_loss: 0.0071
# Epoch 55/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0338
# Epoch 55: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0338 - val_loss: 0.0064
# Epoch 56/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0323
# Epoch 56: val_loss did not improve from 0.00516
# 11/11 [==============================] - 3s 291ms/step - loss: 0.0323 - val_loss: 0.0090
# Epoch 57/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 57: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0160 - val_loss: 0.0086
# Epoch 58/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 58: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0259 - val_loss: 0.0073
# Epoch 59/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 59: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0385 - val_loss: 0.0076
# Epoch 60/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 60: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0349 - val_loss: 0.0097
# Epoch 61/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0315
# Epoch 61: val_loss did not improve from 0.00516
# 11/11 [==============================] - 3s 242ms/step - loss: 0.0315 - val_loss: 0.0104
# Epoch 62/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 62: val_loss did not improve from 0.00516
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0314 - val_loss: 0.0072
# Epoch 63/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 63: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0225 - val_loss: 0.0073
# Epoch 64/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 64: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0173 - val_loss: 0.0078
# Epoch 65/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 65: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 229ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 66/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 66: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0193 - val_loss: 0.0089
# Epoch 67/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 67: val_loss did not improve from 0.00516
# 11/11 [==============================] - 3s 324ms/step - loss: 0.0239 - val_loss: 0.0074
# Epoch 68/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 68: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0148 - val_loss: 0.0061
# Epoch 69/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 69: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0141 - val_loss: 0.0067
# Epoch 70/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 70: val_loss did not improve from 0.00516
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0177 - val_loss: 0.0059
# Epoch 71/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 71: val_loss improved from 0.00516 to 0.00446, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 548ms/step - loss: 0.0219 - val_loss: 0.0045
# Epoch 72/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 72: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0218 - val_loss: 0.0048
# Epoch 73/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 73: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0132 - val_loss: 0.0059
# Epoch 74/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 74: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0161 - val_loss: 0.0048
# Epoch 75/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0251
# Epoch 75: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0251 - val_loss: 0.0048
# Epoch 76/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 76: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0111 - val_loss: 0.0052
# Epoch 77/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0234
# Epoch 77: val_loss did not improve from 0.00446
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0234 - val_loss: 0.0063
# Epoch 78/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 78: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0126 - val_loss: 0.0063
# Epoch 79/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 79: val_loss did not improve from 0.00446
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0123 - val_loss: 0.0055
# Epoch 80/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 80: val_loss improved from 0.00446 to 0.00441, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0160 - val_loss: 0.0044
# Epoch 81/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 81: val_loss improved from 0.00441 to 0.00281, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 599ms/step - loss: 0.0195 - val_loss: 0.0028
# Epoch 82/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 82: val_loss improved from 0.00281 to 0.00217, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 480ms/step - loss: 0.0130 - val_loss: 0.0022
# Epoch 83/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 83: val_loss improved from 0.00217 to 0.00192, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 568ms/step - loss: 0.0108 - val_loss: 0.0019
# Epoch 84/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 84: val_loss improved from 0.00192 to 0.00168, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 472ms/step - loss: 0.0135 - val_loss: 0.0017
# Epoch 85/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 85: val_loss did not improve from 0.00168
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0203 - val_loss: 0.0024
# Epoch 86/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 86: val_loss did not improve from 0.00168
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0170 - val_loss: 0.0025
# Epoch 87/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 87: val_loss did not improve from 0.00168
# 11/11 [==============================] - 3s 300ms/step - loss: 0.0202 - val_loss: 0.0019
# Epoch 88/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 88: val_loss did not improve from 0.00168
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0221 - val_loss: 0.0017
# Epoch 89/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0102
# Epoch
400
# 11/11 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 185: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0111 - val_loss: 0.0055
# Epoch 186/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 186: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0072 - val_loss: 0.0052
# Epoch 187/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 187: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0085 - val_loss: 0.0043
# Epoch 188/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 188: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 189/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 189: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 256ms/step - loss: 0.0091 - val_loss: 0.0055
# Epoch 190/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 190: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 238ms/step - loss: 0.0072 - val_loss: 0.0051
# Epoch 191/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 191: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0090 - val_loss: 0.0048
# Epoch 192/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 192: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0067 - val_loss: 0.0039
# Epoch 193/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 193: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0083 - val_loss: 0.0032
# Epoch 194/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 194: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 195/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 195: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 281ms/step - loss: 0.0091 - val_loss: 0.0038
# Epoch 196/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 196: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0086 - val_loss: 0.0052
# Epoch 197/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 197: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0088 - val_loss: 0.0049
# Epoch 198/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 198: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0093 - val_loss: 0.0055
# Epoch 199/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 199: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 200/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 200: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 283ms/step - loss: 0.0071 - val_loss: 0.0048
# Epoch 201/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 201: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 222ms/step - loss: 0.0080 - val_loss: 0.0044
# Epoch 202/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 202: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0068 - val_loss: 0.0056
# Epoch 203/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 203: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0129 - val_loss: 0.0052
# Epoch 204/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 204: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0075 - val_loss: 0.0046
# Epoch 205/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 205: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0067 - val_loss: 0.0047
# Epoch 206/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 206: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0099 - val_loss: 0.0035
# Epoch 207/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 207: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0132 - val_loss: 0.0027
# Epoch 208/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 208: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0088 - val_loss: 0.0036
# Epoch 209/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 209: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0091 - val_loss: 0.0034
# Epoch 210/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 210: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0074 - val_loss: 0.0034
# Epoch 211/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 211: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 303ms/step - loss: 0.0089 - val_loss: 0.0053
# Epoch 212/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 212: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0086 - val_loss: 0.0050
# Epoch 213/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 213: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0088 - val_loss: 0.0050
# Epoch 214/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 214: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 215/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 215: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0120 - val_loss: 0.0031
# Epoch 216/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 216: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0077 - val_loss: 0.0029
# Epoch 217/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 217: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0079 - val_loss: 0.0031
# Epoch 218/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 218: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0134 - val_loss: 0.0032
# Epoch 219/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 219: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0077 - val_loss: 0.0031
# Epoch 220/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 220: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0072 - val_loss: 0.0032
# Epoch 221/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 221: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 222/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 222: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 283ms/step - loss: 0.0093 - val_loss: 0.0033
# Epoch 223/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 223: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0115 - val_loss: 0.0028
# Epoch 224/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 224: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0103 - val_loss: 0.0026
# Epoch 225/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 225: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0086 - val_loss: 0.0025
# Epoch 226/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 226: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0089 - val_loss: 0.0034
# Epoch 227/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 227: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 295ms/step - loss: 0.0091 - val_loss: 0.0037
# Epoch 228/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 228: val_loss did not improve from 0.00158
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 229/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0099Restoring model weights from the end of the best epoch: 159.
#
# Epoch 229: val_loss did not improve from 0.00158
# 11/11 [==============================] - 3s 250ms/step - loss: 0.0099 - val_loss: 0.0043
# Epoch 229: early stopping
# Training time: 0:15:36.488088

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (267680689, 269256500)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.004721027333289385
# Validation loss 0.0015783263370394707

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX1.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.2,1.2])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.2,1.2])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 3/3 [==============================] - 11s 38ms/step
# 2/2 [==============================] - 9s 41ms/step

# %%
test_dev = abs(pred_test-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.060122382647542216
# Mean absolute deviation: 0.12323395557520392
# RMS deviation: 0.2451986595549458
# MAPE: inf
# <ipython-input-47-45939981446d>:10: RuntimeWarning: divide by zero encountered in divide
#   MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
