# %%
pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences

# dimension of data sequences
n_dim = 88 # dimension after segmenting the data into body parts
batch_size = 2

# %%
import joblib

exercise = 'E1'
split_no = '3'

split_data_path = '/content/' + exercise + '_split_' + split_no + '.pkl'
split_data = joblib.load(split_data_path)

X_train = split_data['train']['data']
y_train = split_data['train']['labels']

X_test = split_data['test']['data']
y_test = split_data['test']['labels']

train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

test_x = X_test
test_y = y_test

# %%
import numpy as np

# Replace NaN values with mean in training data
nan_mask_train_X = np.isnan(X_train)
mean_values_train_X = np.nanmean(X_train)
X_train[nan_mask_train_X] = mean_values_train_X

nan_mask_train_y = np.isnan(y_train)
mean_values_train_y = np.nanmean(y_train)
y_train[nan_mask_train_y] = mean_values_train_y

# Replace NaN values with mean in testing data
nan_mask_test_X = np.isnan(X_test)
mean_values_test_X = np.nanmean(X_test)
X_test[nan_mask_test_X] = mean_values_test_X

nan_mask_test_y = np.isnan(y_test)
mean_values_test_y = np.nanmean(y_test)
y_test[nan_mask_test_y] = mean_values_test_y


print("The X_train size is ", X_train.shape)
print("The y_train size is ", y_train.shape)
print("The X_test size is ", X_test.shape)
print("The y_test size is ", y_test.shape)



def makeDataDivisibleBy8(myData):
    newData = []
    for file in myData:
      file_length = file.shape[0]
      new_length = file.shape[0]

      while (new_length % 8) != 0:
        new_length += 1
        print("New length is ", new_length)

      print("The desired length is ", new_length)

      rows_to_append = new_length - file_length

      zero_rows = np.zeros((rows_to_append, file.shape[1]))
      file = np.vstack([file, zero_rows])
      newData.append(file)

    print("The size after zero stacking is ", newData[0].shape)

    return np.array(newData)


train_x = makeDataDivisibleBy8(train_x)
valid_x = makeDataDivisibleBy8(valid_x)
test_x  = makeDataDivisibleBy8(test_x)

timesteps = train_x.shape[1]
# Out:
# The X_train size is  (120, 180, 132)
# The y_train size is  (120,)
# The X_test size is  (40, 180, 132)
# The y_test size is  (40,)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
testx = test_x

trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)

trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)

trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)


trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]

trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]

trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
# Code to re-order the 132 dimensional skeleton data from the mediapipe sekeleton into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],16))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],16))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],16))

    X_trunk =  np.concatenate((x[:,:,44:52], x[:,:,92:100]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,52:56], x[:,:,60:64], x[:,:,68:72], x[:,:,76:80], x[:,:,84:88]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,56:60], x[:,:,64:68], x[:,:,72:76], x[:,:,80:84], x[:,:,88:92]), axis = 2)
    X_left_leg = np.concatenate((x[:,:,100:104], x[:,:,108:112], x[:,:,116:120], x[:,:,124:128]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,104:108], x[:,:,112:116], x[:,:,120:124], x[:,:,128:132]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented


# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
test_x =  reorder_data(test_x)

trainx_2 =  reorder_data(trainx_2)
validx_2 =  reorder_data(validx_2)
testx_2 = reorder_data(testx_2)

trainx_4 =  reorder_data(trainx_4)
validx_4 =  reorder_data(validx_4)
testx_4 = reorder_data(testx_4)

trainx_8 =  reorder_data(trainx_8)
validx_8 =  reorder_data(validx_8)
testx_8 = reorder_data(testx_8)

# %%
print(trainx.shape)
print(validx.shape)
print(test_x.shape)

print(trainx_2.shape)
print(validx_2.shape)
print(testx_2.shape)

print(trainx_4.shape)
print(validx_4.shape)
print(testx_4.shape)

print(trainx_8.shape)
print(validx_8.shape)
print(testx_8.shape)
# Out:
# (72, 184, 88)
# (48, 184, 88)
# (40, 184, 88)
# (72, 92, 88)
# (48, 92, 88)
# (40, 92, 88)
# (72, 46, 88)
# (48, 46, 88)
# (40, 46, 88)
# (72, 23, 88)
# (48, 23, 88)
# (40, 23, 88)

# %%
n_dim = 88 # dimension after segmenting the data into body parts
n_dim1 = 16 # trunk dimension
n_dim2 = 20 # arms dimension
n_dim3 = 16 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 17:36])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 37:56])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 57:72])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 73:88])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 17:36])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 37:56])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 57:72])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 73:88])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 17:36])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 37:56])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 57:72])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 73:88])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 17:36])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 37:56])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 57:72])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 73:88])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 16)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 16)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 16)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 16)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 184, 88)]            0         []
#
#  half_scale (InputLayer)     [(None, 92, 88)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 46, 88)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 23, 88)]             0         []
#
#  lambda (Lambda)             (None, 184, 16)              0         ['full_scale[0][0]']
#
#  lambda_5 (Lambda)           (None, 92, 16)               0         ['half_scale[0][0]']
#
#  lambda_10 (Lambda)          (None, 46, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)          (None, 23, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)           (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_6 (Lambda)           (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_11 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)           (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_7 (Lambda)           (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_12 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)           (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_8 (Lambda)           (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_13 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)           (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_9 (Lambda)           (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_14 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  tcn (TCN)                   (None, 184, 12)              5676      ['lambda[0][0]']
#
#  tcn_1 (TCN)                 (None, 92, 12)               5676      ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                 (None, 46, 12)               5676      ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                 (None, 23, 12)               5676      ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                 (None, 184, 12)              5820      ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                 (None, 92, 12)               5820      ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                 (None, 46, 12)               5820      ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                 (None, 23, 12)               5820      ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                 (None, 184, 12)              5820      ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                 (None, 92, 12)               5820      ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                (None, 46, 12)               5820      ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                (None, 23, 12)               5820      ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                (None, 184, 12)              5628      ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                (None, 92, 12)               5628      ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                (None, 46, 12)               5628      ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                (None, 23, 12)               5628      ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                (None, 184, 12)              5628      ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                (None, 92, 12)               5628      ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                (None, 46, 12)               5628      ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                (None, 23, 12)               5628      ['lambda_19[0][0]']
#
#  concatenate (Concatenate)   (None, 345, 12)              0         ['tcn[0][0]',
#                                                                      'tcn_1[0][0]',
#                                                                      'tcn_2[0][0]',
#                                                                      'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 345, 12)              0         ['tcn_4[0][0]',
#  )                                                                   'tcn_5[0][0]',
#                                                                      'tcn_6[0][0]',
#                                                                      'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 345, 12)              0         ['tcn_8[0][0]',
#  )                                                                   'tcn_9[0][0]',
#                                                                      'tcn_10[0][0]',
#                                                                      'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate  (None, 345, 12)              0         ['tcn_12[0][0]',
#  )                                                                   'tcn_13[0][0]',
#                                                                      'tcn_14[0][0]',
#                                                                      'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate  (None, 345, 12)              0         ['tcn_16[0][0]',
#  )                                                                   'tcn_17[0][0]',
#                                                                      'tcn_18[0][0]',
#                                                                      'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate  (None, 345, 60)              0         ['concatenate[0][0]',
#  )                                                                   'concatenate_1[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                (None, 345, 12)              6012      ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                (None, 345, 8)               1176      ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                (None, 6)                    546       ['tcn_21[0][0]']
#
#  dense (Dense)               (None, 1)                    7         ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 122029 (476.68 KB)
# Trainable params: 121933 (476.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 11/11 [==============================] - ETA: 0s - loss: 0.4581
# Epoch 1: val_loss improved from inf to 0.51978, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 11/11 [==============================] - 282s 3s/step - loss: 0.4581 - val_loss: 0.5198
# Epoch 2/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1622
# Epoch 2: val_loss did not improve from 0.51978
# 11/11 [==============================] - 3s 302ms/step - loss: 0.1622 - val_loss: 0.7221
# Epoch 3/400
# 11/11 [==============================] - ETA: 0s - loss: 0.2077
# Epoch 3: val_loss did not improve from 0.51978
# 11/11 [==============================] - 3s 288ms/step - loss: 0.2077 - val_loss: 0.5256
# Epoch 4/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1560
# Epoch 4: val_loss improved from 0.51978 to 0.38600, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 509ms/step - loss: 0.1560 - val_loss: 0.3860
# Epoch 5/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1602
# Epoch 5: val_loss improved from 0.38600 to 0.28789, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 582ms/step - loss: 0.1602 - val_loss: 0.2879
# Epoch 6/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1078
# Epoch 6: val_loss improved from 0.28789 to 0.26812, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 513ms/step - loss: 0.1078 - val_loss: 0.2681
# Epoch 7/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1212
# Epoch 7: val_loss improved from 0.26812 to 0.21301, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 499ms/step - loss: 0.1212 - val_loss: 0.2130
# Epoch 8/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0868
# Epoch 8: val_loss improved from 0.21301 to 0.17379, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 7s 662ms/step - loss: 0.0868 - val_loss: 0.1738
# Epoch 9/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0999
# Epoch 9: val_loss improved from 0.17379 to 0.13570, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 492ms/step - loss: 0.0999 - val_loss: 0.1357
# Epoch 10/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1206
# Epoch 10: val_loss improved from 0.13570 to 0.10614, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 632ms/step - loss: 0.1206 - val_loss: 0.1061
# Epoch 11/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0696
# Epoch 11: val_loss improved from 0.10614 to 0.08166, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 508ms/step - loss: 0.0696 - val_loss: 0.0817
# Epoch 12/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 12: val_loss improved from 0.08166 to 0.06225, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 608ms/step - loss: 0.0624 - val_loss: 0.0622
# Epoch 13/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0930
# Epoch 13: val_loss improved from 0.06225 to 0.05953, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 494ms/step - loss: 0.0930 - val_loss: 0.0595
# Epoch 14/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0722
# Epoch 14: val_loss improved from 0.05953 to 0.04546, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 490ms/step - loss: 0.0722 - val_loss: 0.0455
# Epoch 15/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0886
# Epoch 15: val_loss improved from 0.04546 to 0.03353, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 618ms/step - loss: 0.0886 - val_loss: 0.0335
# Epoch 16/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 16: val_loss improved from 0.03353 to 0.02884, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 488ms/step - loss: 0.0884 - val_loss: 0.0288
# Epoch 17/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0793
# Epoch 17: val_loss improved from 0.02884 to 0.01225, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 598ms/step - loss: 0.0793 - val_loss: 0.0122
# Epoch 18/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1010
# Epoch 18: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 203ms/step - loss: 0.1010 - val_loss: 0.0141
# Epoch 19/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 19: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0828 - val_loss: 0.0303
# Epoch 20/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 20: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0779 - val_loss: 0.0195
# Epoch 21/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0666
# Epoch 21: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0666 - val_loss: 0.0204
# Epoch 22/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0912
# Epoch 22: val_loss did not improve from 0.01225
# 11/11 [==============================] - 4s 333ms/step - loss: 0.0912 - val_loss: 0.0228
# Epoch 23/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0630
# Epoch 23: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0630 - val_loss: 0.0179
# Epoch 24/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 24: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0616 - val_loss: 0.0143
# Epoch 25/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0751
# Epoch 25: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0751 - val_loss: 0.0144
# Epoch 26/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0842
# Epoch 26: val_loss did not improve from 0.01225
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0842 - val_loss: 0.0135
# Epoch 27/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0636
# Epoch 27: val_loss improved from 0.01225 to 0.00922, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 618ms/step - loss: 0.0636 - val_loss: 0.0092
# Epoch 28/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0606
# Epoch 28: val_loss improved from 0.00922 to 0.00855, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 511ms/step - loss: 0.0606 - val_loss: 0.0085
# Epoch 29/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0598
# Epoch 29: val_loss did not improve from 0.00855
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0598 - val_loss: 0.0095
# Epoch 30/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0696
# Epoch 30: val_loss did not improve from 0.00855
# 11/11 [==============================] - 4s 353ms/step - loss: 0.0696 - val_loss: 0.0092
# Epoch 31/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 31: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 224ms/step - loss: 0.0548 - val_loss: 0.0097
# Epoch 32/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 32: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0624 - val_loss: 0.0102
# Epoch 33/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0606
# Epoch 33: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0606 - val_loss: 0.0100
# Epoch 34/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0706
# Epoch 34: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0706 - val_loss: 0.0090
# Epoch 35/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 35: val_loss did not improve from 0.00855
# 11/11 [==============================] - 3s 328ms/step - loss: 0.0624 - val_loss: 0.0086
# Epoch 36/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0706
# Epoch 36: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0706 - val_loss: 0.0096
# Epoch 37/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0738
# Epoch 37: val_loss did not improve from 0.00855
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0738 - val_loss: 0.0095
# Epoch 38/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0584
# Epoch 38: val_loss improved from 0.00855 to 0.00801, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 491ms/step - loss: 0.0584 - val_loss: 0.0080
# Epoch 39/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 39: val_loss did not improve from 0.00801
# 11/11 [==============================] - 4s 359ms/step - loss: 0.0443 - val_loss: 0.0089
# Epoch 40/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0814
# Epoch 40: val_loss did not improve from 0.00801
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0814 - val_loss: 0.0110
# Epoch 41/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 41: val_loss improved from 0.00801 to 0.00645, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 487ms/step - loss: 0.0517 - val_loss: 0.0064
# Epoch 42/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0460
# Epoch 42: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0460 - val_loss: 0.0085
# Epoch 43/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0472
# Epoch 43: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 329ms/step - loss: 0.0472 - val_loss: 0.0073
# Epoch 44/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 44: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0616 - val_loss: 0.0080
# Epoch 45/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0604
# Epoch 45: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0604 - val_loss: 0.0070
# Epoch 46/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 46: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0435 - val_loss: 0.0120
# Epoch 47/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0555
# Epoch 47: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0555 - val_loss: 0.0076
# Epoch 48/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 48: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0436 - val_loss: 0.0074
# Epoch 49/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 49: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 300ms/step - loss: 0.0422 - val_loss: 0.0072
# Epoch 50/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0534
# Epoch 50: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0534 - val_loss: 0.0103
# Epoch 51/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 51: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0571 - val_loss: 0.0107
# Epoch 52/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0560
# Epoch 52: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0560 - val_loss: 0.0100
# Epoch 53/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 53: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 217ms/step - loss: 0.0439 - val_loss: 0.0103
# Epoch 54/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 54: val_loss did not improve from 0.00645
# 11/11 [==============================] - 4s 324ms/step - loss: 0.0456 - val_loss: 0.0104
# Epoch 55/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0534
# Epoch 55: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0534 - val_loss: 0.0162
# Epoch 56/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 56: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0593 - val_loss: 0.0072
# Epoch 57/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 57: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 225ms/step - loss: 0.0312 - val_loss: 0.0085
# Epoch 58/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 58: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0439 - val_loss: 0.0105
# Epoch 59/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0402
# Epoch 59: val_loss did not improve from 0.00645
# 11/11 [==============================] - 4s 339ms/step - loss: 0.0402 - val_loss: 0.0067
# Epoch 60/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0399
# Epoch 60: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0399 - val_loss: 0.0095
# Epoch 61/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0472
# Epoch 61: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0472 - val_loss: 0.0086
# Epoch 62/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0403
# Epoch 62: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0403 - val_loss: 0.0080
# Epoch 63/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0497
# Epoch 63: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0497 - val_loss: 0.0069
# Epoch 64/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0320
# Epoch 64: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0320 - val_loss: 0.0083
# Epoch 65/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0540
# Epoch 65: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 302ms/step - loss: 0.0540 - val_loss: 0.0089
# Epoch 66/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 66: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0449 - val_loss: 0.0084
# Epoch 67/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 67: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0420 - val_loss: 0.0067
# Epoch 68/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0466
# Epoch 68: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0466 - val_loss: 0.0078
# Epoch 69/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0394
# Epoch 69: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 238ms/step - loss: 0.0394 - val_loss: 0.0109
# Epoch 70/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0372
# Epoch 70: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 307ms/step - loss: 0.0372 - val_loss: 0.0106
# Epoch 71/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 71: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0435 - val_loss: 0.0106
# Epoch 72/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0326
# Epoch 72: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0326 - val_loss: 0.0099
# Epoch 73/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 73: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0450 - val_loss: 0.0107
# Epoch 74/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 74: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0439 - val_loss: 0.0080
# Epoch 75/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 75: val_loss did not improve from 0.00645
# 11/11 [==============================] - 4s 338ms/step - loss: 0.0340 - val_loss: 0.0088
# Epoch 76/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 76: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0364 - val_loss: 0.0097
# Epoch 77/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0352
# Epoch 77: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0352 - val_loss: 0.0096
# Epoch 78/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0390
# Epoch 78: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0390 - val_loss: 0.0092
# Epoch 79/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 79: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0355 - val_loss: 0.0078
# Epoch 80/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 80: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0314 - val_loss: 0.0085
# Epoch 81/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 81: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0358 - val_loss: 0.0087
# Epoch 82/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 82: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0375 - val_loss: 0.0083
# Epoch 83/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 83: val_loss did not improve from 0.00645
# 11/11 [==============================] - 3s 234ms/step - loss: 0.0423 - val_loss: 0.0079
# Epoch 84/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 84: val_loss did not improve from 0.00645
# 11/11 [==============================] - 2s 225ms/step - loss: 0.0301 - val_loss: 0.0067
# Epoch 85/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0329
# Epoch 85: val_loss improved from 0.00645 to 0.00642, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 627ms/step - loss: 0.0329 - val_loss: 0.0064
# Epoch 86/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 86: val_loss did not improve from 0.00642
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0446 - val_loss: 0.0073
# Epoch 87/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 87: val_loss did not improve from 0.00642
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0444 - val_loss: 0.0069
# Epoch 88/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 88: val_loss improved from 0.00642 to 0.00550, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 527ms/step - loss: 0.0419 - val_loss: 0.0055
# Epoch 89/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 89: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 302ms/step - loss: 0.0366 - val_loss: 0.0066
# Epoch 90/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 90: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0364 - val_loss: 0.0087
# Epoch 91/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 91: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 234ms/step - loss: 0.0345 - val_loss: 0.0067
# Epoch 92/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 92: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0385 - val_loss: 0.0129
# Epoch 93/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 93: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0424 - val_loss: 0.0155
# Epoch 94/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 94: val_loss did not improve from 0.00550
# 11/11 [==============================] - 4s 336ms/step - loss: 0.0362 - val_loss: 0.0117
# Epoch 95/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 95: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0334 - val_loss: 0.0106
# Epoch 96/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 96: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0369 - val_loss: 0.0095
# Epoch 97/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0402
# Epoch 97: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 203ms/step - loss: 0.
400
# 11/11 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 168: val_loss did not improve from 0.00550
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0192 - val_loss: 0.0072
# Epoch 169/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0338
# Epoch 169: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0338 - val_loss: 0.0082
# Epoch 170/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 170: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0355 - val_loss: 0.0092
# Epoch 171/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 171: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0246 - val_loss: 0.0081
# Epoch 172/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 172: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0200 - val_loss: 0.0088
# Epoch 173/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 173: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 330ms/step - loss: 0.0265 - val_loss: 0.0083
# Epoch 174/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 174: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 230ms/step - loss: 0.0224 - val_loss: 0.0123
# Epoch 175/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0457
# Epoch 175: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0457 - val_loss: 0.0135
# Epoch 176/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 176: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0259 - val_loss: 0.0099
# Epoch 177/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 177: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0279 - val_loss: 0.0064
# Epoch 178/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 178: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 302ms/step - loss: 0.0219 - val_loss: 0.0058
# Epoch 179/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 179: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0248 - val_loss: 0.0057
# Epoch 180/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 180: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0242 - val_loss: 0.0058
# Epoch 181/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0250
# Epoch 181: val_loss did not improve from 0.00550
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0250 - val_loss: 0.0056
# Epoch 182/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 182: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0216 - val_loss: 0.0061
# Epoch 183/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 183: val_loss did not improve from 0.00550
# 11/11 [==============================] - 3s 259ms/step - loss: 0.0306 - val_loss: 0.0056
# Epoch 184/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0313
# Epoch 184: val_loss improved from 0.00550 to 0.00548, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 612ms/step - loss: 0.0313 - val_loss: 0.0055
# Epoch 185/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 185: val_loss improved from 0.00548 to 0.00538, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 498ms/step - loss: 0.0247 - val_loss: 0.0054
# Epoch 186/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 186: val_loss did not improve from 0.00538
# 11/11 [==============================] - 3s 324ms/step - loss: 0.0287 - val_loss: 0.0058
# Epoch 187/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 187: val_loss did not improve from 0.00538
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0275 - val_loss: 0.0060
# Epoch 188/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0229
# Epoch 188: val_loss did not improve from 0.00538
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0229 - val_loss: 0.0081
# Epoch 189/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 189: val_loss did not improve from 0.00538
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0238 - val_loss: 0.0082
# Epoch 190/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 190: val_loss did not improve from 0.00538
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0219 - val_loss: 0.0085
# Epoch 191/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 191: val_loss did not improve from 0.00538
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0274 - val_loss: 0.0081
# Epoch 192/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 192: val_loss did not improve from 0.00538
# 11/11 [==============================] - 3s 258ms/step - loss: 0.0288 - val_loss: 0.0058
# Epoch 193/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 193: val_loss did not improve from 0.00538
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0265 - val_loss: 0.0060
# Epoch 194/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 194: val_loss improved from 0.00538 to 0.00506, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 499ms/step - loss: 0.0224 - val_loss: 0.0051
# Epoch 195/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 195: val_loss did not improve from 0.00506
# 11/11 [==============================] - 3s 308ms/step - loss: 0.0244 - val_loss: 0.0061
# Epoch 196/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0209
# Epoch 196: val_loss did not improve from 0.00506
# 11/11 [==============================] - 3s 255ms/step - loss: 0.0209 - val_loss: 0.0077
# Epoch 197/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 197: val_loss did not improve from 0.00506
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0296 - val_loss: 0.0069
# Epoch 198/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0251
# Epoch 198: val_loss did not improve from 0.00506
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0251 - val_loss: 0.0059
# Epoch 199/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 199: val_loss did not improve from 0.00506
# 11/11 [==============================] - 3s 260ms/step - loss: 0.0150 - val_loss: 0.0057
# Epoch 200/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0332
# Epoch 200: val_loss did not improve from 0.00506
# 11/11 [==============================] - 3s 279ms/step - loss: 0.0332 - val_loss: 0.0053
# Epoch 201/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 201: val_loss did not improve from 0.00506
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0178 - val_loss: 0.0053
# Epoch 202/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 202: val_loss did not improve from 0.00506
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0206 - val_loss: 0.0051
# Epoch 203/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 203: val_loss improved from 0.00506 to 0.00502, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 500ms/step - loss: 0.0277 - val_loss: 0.0050
# Epoch 204/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 204: val_loss did not improve from 0.00502
# 11/11 [==============================] - 3s 327ms/step - loss: 0.0242 - val_loss: 0.0050
# Epoch 205/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 205: val_loss did not improve from 0.00502
# 11/11 [==============================] - 4s 365ms/step - loss: 0.0202 - val_loss: 0.0060
# Epoch 206/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 206: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 223ms/step - loss: 0.0210 - val_loss: 0.0066
# Epoch 207/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 207: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0178 - val_loss: 0.0059
# Epoch 208/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 208: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0218 - val_loss: 0.0058
# Epoch 209/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 209: val_loss did not improve from 0.00502
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0245 - val_loss: 0.0056
# Epoch 210/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0232
# Epoch 210: val_loss did not improve from 0.00502
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0232 - val_loss: 0.0078
# Epoch 211/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 211: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0183 - val_loss: 0.0082
# Epoch 212/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 212: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0145 - val_loss: 0.0073
# Epoch 213/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 213: val_loss did not improve from 0.00502
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0200 - val_loss: 0.0074
# Epoch 214/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 214: val_loss did not improve from 0.00502
# ...
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0132 - val_loss: 0.0061
# Epoch 289/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 289: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0090 - val_loss: 0.0058
# Epoch 290/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 290: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0080 - val_loss: 0.0058
# Epoch 291/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 291: val_loss did not improve from 0.00441
# 11/11 [==============================] - 3s 237ms/step - loss: 0.0043 - val_loss: 0.0057
# Epoch 292/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 292: val_loss did not improve from 0.00441
# 11/11 [==============================] - 4s 336ms/step - loss: 0.0087 - val_loss: 0.0062
# Epoch 293/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 293: val_loss did not improve from 0.00441
# 11/11 [==============================] - 3s 237ms/step - loss: 0.0097 - val_loss: 0.0073
# Epoch 294/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 294: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0103 - val_loss: 0.0063
# Epoch 295/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 295: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0081 - val_loss: 0.0057
# Epoch 296/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 296: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0121 - val_loss: 0.0067
# Epoch 297/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 297: val_loss did not improve from 0.00441
# 11/11 [==============================] - 4s 366ms/step - loss: 0.0130 - val_loss: 0.0071
# Epoch 298/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 298: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 299/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 299: val_loss did not improve from 0.00441
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 300/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 300: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0157 - val_loss: 0.0050
# Epoch 301/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 301: val_loss did not improve from 0.00441
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0105 - val_loss: 0.0049
# Epoch 302/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0097
# Epoch