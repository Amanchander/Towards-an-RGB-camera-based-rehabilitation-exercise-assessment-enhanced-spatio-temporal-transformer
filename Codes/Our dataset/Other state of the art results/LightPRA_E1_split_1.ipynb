# %%
pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Collecting tensorflow-addons (from keras-tcn)
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->keras-tcn)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)
# Installing collected packages: typeguard, tensorflow-addons, keras-tcn
# Successfully installed keras-tcn-3.5.0 tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences

# dimension of data sequences
n_dim = 88 # dimension after segmenting the data into body parts
batch_size = 2

# %%
import joblib

exercise = 'E1'
split_no = '1'

split_data_path = '/content/' + exercise + '_split_' + split_no + '.pkl'
split_data = joblib.load(split_data_path)

X_train = split_data['train']['data']
y_train = split_data['train']['labels']

X_test = split_data['test']['data']
y_test = split_data['test']['labels']

train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

test_x = X_test
test_y = y_test

# %%
import numpy as np

# Replace NaN values with mean in training data
nan_mask_train_X = np.isnan(X_train)
mean_values_train_X = np.nanmean(X_train)
X_train[nan_mask_train_X] = mean_values_train_X

nan_mask_train_y = np.isnan(y_train)
mean_values_train_y = np.nanmean(y_train)
y_train[nan_mask_train_y] = mean_values_train_y

# Replace NaN values with mean in testing data
nan_mask_test_X = np.isnan(X_test)
mean_values_test_X = np.nanmean(X_test)
X_test[nan_mask_test_X] = mean_values_test_X

nan_mask_test_y = np.isnan(y_test)
mean_values_test_y = np.nanmean(y_test)
y_test[nan_mask_test_y] = mean_values_test_y


print("The X_train size is ", X_train.shape)
print("The y_train size is ", y_train.shape)
print("The X_test size is ", X_test.shape)
print("The y_test size is ", y_test.shape)



def makeDataDivisibleBy8(myData):
    newData = []
    for file in myData:
      file_length = file.shape[0]
      new_length = file.shape[0]

      while (new_length % 8) != 0:
        new_length += 1
        print("New length is ", new_length)

      print("The desired length is ", new_length)

      rows_to_append = new_length - file_length

      zero_rows = np.zeros((rows_to_append, file.shape[1]))
      file = np.vstack([file, zero_rows])
      newData.append(file)

    print("The size after zero stacking is ", newData[0].shape)

    return np.array(newData)


train_x = makeDataDivisibleBy8(train_x)
valid_x = makeDataDivisibleBy8(valid_x)
test_x  = makeDataDivisibleBy8(test_x)

timesteps = train_x.shape[1]
# Out:
# The X_train size is  (120, 180, 132)
# The y_train size is  (120,)
# The X_test size is  (40, 180, 132)
# The y_test size is  (40,)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# New length is  181
# New length is  182
# New length is  183
# New length is  184
# The desired length is  184
# The size after zero stacking is  (184, 132)

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
testx = test_x

trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)

trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)

trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)


trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]

trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]

trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
# Code to re-order the 132 dimensional skeleton data from the mediapipe sekeleton into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],16))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],20))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],16))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],16))

    X_trunk =  np.concatenate((x[:,:,44:52], x[:,:,92:100]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,52:56], x[:,:,60:64], x[:,:,68:72], x[:,:,76:80], x[:,:,84:88]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,56:60], x[:,:,64:68], x[:,:,72:76], x[:,:,80:84], x[:,:,88:92]), axis = 2)
    X_left_leg = np.concatenate((x[:,:,100:104], x[:,:,108:112], x[:,:,116:120], x[:,:,124:128]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,104:108], x[:,:,112:116], x[:,:,120:124], x[:,:,128:132]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented


# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
test_x =  reorder_data(test_x)

trainx_2 =  reorder_data(trainx_2)
validx_2 =  reorder_data(validx_2)
testx_2 = reorder_data(testx_2)

trainx_4 =  reorder_data(trainx_4)
validx_4 =  reorder_data(validx_4)
testx_4 = reorder_data(testx_4)

trainx_8 =  reorder_data(trainx_8)
validx_8 =  reorder_data(validx_8)
testx_8 = reorder_data(testx_8)

# %%
print(trainx.shape)
print(validx.shape)
print(test_x.shape)

print(trainx_2.shape)
print(validx_2.shape)
print(testx_2.shape)

print(trainx_4.shape)
print(validx_4.shape)
print(testx_4.shape)

print(trainx_8.shape)
print(validx_8.shape)
print(testx_8.shape)
# Out:
# (72, 184, 88)
# (48, 184, 88)
# (40, 184, 88)
# (72, 92, 88)
# (48, 92, 88)
# (40, 92, 88)
# (72, 46, 88)
# (48, 46, 88)
# (40, 46, 88)
# (72, 23, 88)
# (48, 23, 88)
# (40, 23, 88)

# %%
n_dim = 88 # dimension after segmenting the data into body parts
n_dim1 = 16 # trunk dimension
n_dim2 = 20 # arms dimension
n_dim3 = 16 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 17:36])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 37:56])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 57:72])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 73:88])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 17:36])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 37:56])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 57:72])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 73:88])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 17:36])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 37:56])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 57:72])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 73:88])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 17:36])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 37:56])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 57:72])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 73:88])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 16)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 16)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 16)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 16)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 19)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 19)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 19)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 19)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 184, 15)
# shape of tcn_layer:  (None, 184, 12)
# shape of input::  (None, 92, 15)
# shape of tcn_layer:  (None, 92, 12)
# tcn-2:  (None, 92, 12)
# shape of input::  (None, 46, 15)
# shape of tcn_layer:  (None, 46, 12)
# tcn-3:  (None, 46, 12)
# shape of input::  (None, 23, 15)
# shape of tcn_layer:  (None, 23, 12)
# tcn-5:  (None, 23, 12)
# final_tcn:  (None, 345, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 184, 88)]            0         []
#
#  half_scale (InputLayer)     [(None, 92, 88)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 46, 88)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 23, 88)]             0         []
#
#  lambda (Lambda)             (None, 184, 16)              0         ['full_scale[0][0]']
#
#  lambda_5 (Lambda)           (None, 92, 16)               0         ['half_scale[0][0]']
#
#  lambda_10 (Lambda)          (None, 46, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)          (None, 23, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)           (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_6 (Lambda)           (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_11 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)           (None, 184, 19)              0         ['full_scale[0][0]']
#
#  lambda_7 (Lambda)           (None, 92, 19)               0         ['half_scale[0][0]']
#
#  lambda_12 (Lambda)          (None, 46, 19)               0         ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)          (None, 23, 19)               0         ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)           (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_8 (Lambda)           (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_13 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)           (None, 184, 15)              0         ['full_scale[0][0]']
#
#  lambda_9 (Lambda)           (None, 92, 15)               0         ['half_scale[0][0]']
#
#  lambda_14 (Lambda)          (None, 46, 15)               0         ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)          (None, 23, 15)               0         ['eighth_scale[0][0]']
#
#  tcn (TCN)                   (None, 184, 12)              5676      ['lambda[0][0]']
#
#  tcn_1 (TCN)                 (None, 92, 12)               5676      ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                 (None, 46, 12)               5676      ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                 (None, 23, 12)               5676      ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                 (None, 184, 12)              5820      ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                 (None, 92, 12)               5820      ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                 (None, 46, 12)               5820      ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                 (None, 23, 12)               5820      ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                 (None, 184, 12)              5820      ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                 (None, 92, 12)               5820      ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                (None, 46, 12)               5820      ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                (None, 23, 12)               5820      ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                (None, 184, 12)              5628      ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                (None, 92, 12)               5628      ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                (None, 46, 12)               5628      ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                (None, 23, 12)               5628      ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                (None, 184, 12)              5628      ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                (None, 92, 12)               5628      ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                (None, 46, 12)               5628      ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                (None, 23, 12)               5628      ['lambda_19[0][0]']
#
#  concatenate (Concatenate)   (None, 345, 12)              0         ['tcn[0][0]',
#                                                                      'tcn_1[0][0]',
#                                                                      'tcn_2[0][0]',
#                                                                      'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 345, 12)              0         ['tcn_4[0][0]',
#  )                                                                   'tcn_5[0][0]',
#                                                                      'tcn_6[0][0]',
#                                                                      'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 345, 12)              0         ['tcn_8[0][0]',
#  )                                                                   'tcn_9[0][0]',
#                                                                      'tcn_10[0][0]',
#                                                                      'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate  (None, 345, 12)              0         ['tcn_12[0][0]',
#  )                                                                   'tcn_13[0][0]',
#                                                                      'tcn_14[0][0]',
#                                                                      'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate  (None, 345, 12)              0         ['tcn_16[0][0]',
#  )                                                                   'tcn_17[0][0]',
#                                                                      'tcn_18[0][0]',
#                                                                      'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate  (None, 345, 60)              0         ['concatenate[0][0]',
#  )                                                                   'concatenate_1[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                (None, 345, 12)              6012      ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                (None, 345, 8)               1176      ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                (None, 6)                    546       ['tcn_21[0][0]']
#
#  dense (Dense)               (None, 1)                    7         ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 122029 (476.68 KB)
# Trainable params: 121933 (476.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 11/11 [==============================] - ETA: 0s - loss: 3.0621
# Epoch 1: val_loss improved from inf to 8.46509, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 11/11 [==============================] - 363s 3s/step - loss: 3.0621 - val_loss: 8.4651
# Epoch 2/400
# 11/11 [==============================] - ETA: 0s - loss: 0.6658
# Epoch 2: val_loss improved from 8.46509 to 1.07702, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 547ms/step - loss: 0.6658 - val_loss: 1.0770
# Epoch 3/400
# 11/11 [==============================] - ETA: 0s - loss: 0.3746
# Epoch 3: val_loss improved from 1.07702 to 0.37520, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 538ms/step - loss: 0.3746 - val_loss: 0.3752
# Epoch 4/400
# 11/11 [==============================] - ETA: 0s - loss: 0.2441
# Epoch 4: val_loss improved from 0.37520 to 0.24920, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 501ms/step - loss: 0.2441 - val_loss: 0.2492
# Epoch 5/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1928
# Epoch 5: val_loss did not improve from 0.24920
# 11/11 [==============================] - 3s 332ms/step - loss: 0.1928 - val_loss: 0.2738
# Epoch 6/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1330
# Epoch 6: val_loss improved from 0.24920 to 0.23612, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 504ms/step - loss: 0.1330 - val_loss: 0.2361
# Epoch 7/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1888
# Epoch 7: val_loss improved from 0.23612 to 0.18803, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 489ms/step - loss: 0.1888 - val_loss: 0.1880
# Epoch 8/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1502
# Epoch 8: val_loss improved from 0.18803 to 0.16754, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 556ms/step - loss: 0.1502 - val_loss: 0.1675
# Epoch 9/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1530
# Epoch 9: val_loss improved from 0.16754 to 0.16278, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 478ms/step - loss: 0.1530 - val_loss: 0.1628
# Epoch 10/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1295
# Epoch 10: val_loss improved from 0.16278 to 0.14898, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 582ms/step - loss: 0.1295 - val_loss: 0.1490
# Epoch 11/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1272
# Epoch 11: val_loss improved from 0.14898 to 0.13426, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 505ms/step - loss: 0.1272 - val_loss: 0.1343
# Epoch 12/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1053
# Epoch 12: val_loss improved from 0.13426 to 0.12840, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 577ms/step - loss: 0.1053 - val_loss: 0.1284
# Epoch 13/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0894
# Epoch 13: val_loss improved from 0.12840 to 0.12036, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 499ms/step - loss: 0.0894 - val_loss: 0.1204
# Epoch 14/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1286
# Epoch 14: val_loss improved from 0.12036 to 0.10871, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 471ms/step - loss: 0.1286 - val_loss: 0.1087
# Epoch 15/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0965
# Epoch 15: val_loss improved from 0.10871 to 0.09261, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 560ms/step - loss: 0.0965 - val_loss: 0.0926
# Epoch 16/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 16: val_loss improved from 0.09261 to 0.08282, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 503ms/step - loss: 0.0820 - val_loss: 0.0828
# Epoch 17/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1094
# Epoch 17: val_loss improved from 0.08282 to 0.07529, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 565ms/step - loss: 0.1094 - val_loss: 0.0753
# Epoch 18/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0906
# Epoch 18: val_loss did not improve from 0.07529
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0906 - val_loss: 0.0787
# Epoch 19/400
# 11/11 [==============================] - ETA: 0s - loss: 0.1123
# Epoch 19: val_loss improved from 0.07529 to 0.07020, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 479ms/step - loss: 0.1123 - val_loss: 0.0702
# Epoch 20/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0850
# Epoch 20: val_loss improved from 0.07020 to 0.06794, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 566ms/step - loss: 0.0850 - val_loss: 0.0679
# Epoch 21/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0695
# Epoch 21: val_loss improved from 0.06794 to 0.06176, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 511ms/step - loss: 0.0695 - val_loss: 0.0618
# Epoch 22/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0812
# Epoch 22: val_loss improved from 0.06176 to 0.04820, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 546ms/step - loss: 0.0812 - val_loss: 0.0482
# Epoch 23/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 23: val_loss improved from 0.04820 to 0.04394, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 479ms/step - loss: 0.0872 - val_loss: 0.0439
# Epoch 24/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0722
# Epoch 24: val_loss did not improve from 0.04394
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0722 - val_loss: 0.0510
# Epoch 25/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 25: val_loss did not improve from 0.04394
# 11/11 [==============================] - 2s 222ms/step - loss: 0.0665 - val_loss: 0.0530
# Epoch 26/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0943
# Epoch 26: val_loss did not improve from 0.04394
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0943 - val_loss: 0.0454
# Epoch 27/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0629
# Epoch 27: val_loss improved from 0.04394 to 0.04243, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 515ms/step - loss: 0.0629 - val_loss: 0.0424
# Epoch 28/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0748
# Epoch 28: val_loss improved from 0.04243 to 0.04228, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 485ms/step - loss: 0.0748 - val_loss: 0.0423
# Epoch 29/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0527
# Epoch 29: val_loss did not improve from 0.04228
# 11/11 [==============================] - 3s 317ms/step - loss: 0.0527 - val_loss: 0.0466
# Epoch 30/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 30: val_loss did not improve from 0.04228
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0537 - val_loss: 0.0462
# Epoch 31/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 31: val_loss did not improve from 0.04228
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0593 - val_loss: 0.0446
# Epoch 32/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 32: val_loss improved from 0.04228 to 0.04026, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 479ms/step - loss: 0.0626 - val_loss: 0.0403
# Epoch 33/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0718
# Epoch 33: val_loss improved from 0.04026 to 0.03318, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 564ms/step - loss: 0.0718 - val_loss: 0.0332
# Epoch 34/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 34: val_loss improved from 0.03318 to 0.03305, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 482ms/step - loss: 0.0642 - val_loss: 0.0331
# Epoch 35/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 35: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0543 - val_loss: 0.0379
# Epoch 36/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 36: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0665 - val_loss: 0.0382
# Epoch 37/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 37: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 189ms/step - loss: 0.0675 - val_loss: 0.0364
# Epoch 38/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 38: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0648 - val_loss: 0.0333
# Epoch 39/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0674
# Epoch 39: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0674 - val_loss: 0.0365
# Epoch 40/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0463
# Epoch 40: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 220ms/step - loss: 0.0463 - val_loss: 0.0405
# Epoch 41/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0743
# Epoch 41: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0743 - val_loss: 0.0425
# Epoch 42/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0711
# Epoch 42: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0711 - val_loss: 0.0382
# Epoch 43/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0518
# Epoch 43: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0518 - val_loss: 0.0337
# Epoch 44/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0555
# Epoch 44: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0555 - val_loss: 0.0338
# Epoch 45/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 45: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0587 - val_loss: 0.0387
# Epoch 46/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0504
# Epoch 46: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 245ms/step - loss: 0.0504 - val_loss: 0.0386
# Epoch 47/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 47: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 233ms/step - loss: 0.0593 - val_loss: 0.0361
# Epoch 48/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0501
# Epoch 48: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0501 - val_loss: 0.0362
# Epoch 49/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0816
# Epoch 49: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0816 - val_loss: 0.0333
# Epoch 50/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 50: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 189ms/step - loss: 0.0490 - val_loss: 0.0347
# Epoch 51/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0743
# Epoch 51: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0743 - val_loss: 0.0378
# Epoch 52/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 52: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0592 - val_loss: 0.0385
# Epoch 53/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0686
# Epoch 53: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0686 - val_loss: 0.0367
# Epoch 54/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0582
# Epoch 54: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0582 - val_loss: 0.0373
# Epoch 55/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0477
# Epoch 55: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0477 - val_loss: 0.0352
# Epoch 56/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 56: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0551 - val_loss: 0.0342
# Epoch 57/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0700
# Epoch 57: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0700 - val_loss: 0.0408
# Epoch 58/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 58: val_loss did not improve from 0.03305
# 11/11 [==============================] - 3s 259ms/step - loss: 0.0444 - val_loss: 0.0380
# Epoch 59/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0558
# Epoch 59: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0558 - val_loss: 0.0345
# Epoch 60/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 60: val_loss did not improve from 0.03305
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0587 - val_loss: 0.0360
# Epoch 61/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0499
# Epoch 61: val_loss improved from 0.03305 to 0.03223, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 510ms/step - loss: 0.0499 - val_loss: 0.0322
# Epoch 62/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 62: val_loss improved from 0.03223 to 0.02991, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 520ms/step - loss: 0.0547 - val_loss: 0.0299
# Epoch 63/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 63: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0456 - val_loss: 0.0343
# Epoch 64/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 64: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0561 - val_loss: 0.0356
# Epoch 65/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0539
# Epoch 65: val_loss did not improve from 0.02991
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0539 - val_loss: 0.0335
# Epoch 66/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0412
# Epoch 66: val_loss did not improve from 0.02991
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0412 - val_loss: 0.0322
# Epoch 67/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 67: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0488 - val_loss: 0.0314
# Epoch 68/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 68: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 226ms/step - loss: 0.0340 - val_loss: 0.0319
# Epoch 69/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0502
# Epoch 69: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0502 - val_loss: 0.0325
# Epoch 70/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0434
# Epoch 70: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0434 - val_loss: 0.0334
# Epoch 71/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0379
# Epoch 71: val_loss did not improve from 0.02991
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0379 - val_loss: 0.0325
# Epoch 72/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 72: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0458 - val_loss: 0.0330
# Epoch 73/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 73: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0397 - val_loss: 0.0358
# Epoch 74/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0406
# Epoch 74: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0406 - val_loss: 0.0324
# Epoch 75/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0453
# Epoch 75: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0453 - val_loss: 0.0303
# Epoch 76/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0466
# Epoch 76: val_loss did not improve from 0.02991
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0466 - val_loss: 0.0322
# Epoch 77/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 77: val_loss did not improve from 0.02991
# 11/11 [==============================] - 2s 222ms/step - loss: 0.0576 - val_loss: 0.0310
# Epoch 78/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 78: val_loss improved from 0.02991 to 0.02960, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 472ms/step - loss: 0.0443 - val_loss: 0.0296
# Epoch 79/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 79: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0297 - val_loss: 0.0308
# Epoch 80/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 80: val_loss did not improve from 0.02960
# 11/11 [==============================] - 3s 250ms/step - loss: 0.0513 - val_loss: 0.0322
# Epoch 81/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 81: val_loss did not improve from 0.02960
# 11/11 [==============================] - 3s 252ms/step - loss: 0.0473 - val_loss: 0.0299
# Epoch 82/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0327
# Epoch 82: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0327 - val_loss: 0.0328
# Epoch 83/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0418
# Epoch 83: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0418 - val_loss: 0.0328
# Epoch 84/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0416
# Epoch 84: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0416 - val_loss: 0.0338
# Epoch 85/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0396
# Epoch 85: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0396 - val_loss: 0.0328
# Epoch 86/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 86: val_loss did not improve from 0.02960
# 11/11 [==============================] - 3s 316ms/step - loss: 0.0385 - val_loss: 0.0306
# Epoch 87/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0411
# Epoch 87: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0411 - val_loss: 0.0297
# Epoch 88/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 88: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0443 - val_loss: 0.0317
# Epoch 89/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 89: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0324 - val_loss: 0.0318
# Epoch 90/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0406
# Epoch 90: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0406 - val_loss: 0.0307
# Epoch 91/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0400
# Epoch 91: val_loss did not improve from 0.02960
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0400 - val_loss: 0.0303
# Epoch 92/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 92: val_loss did not improve from 0.02960
# 11/11 [==============================] - 3s 230ms/step - loss: 0.0430 - val_loss: 0.0309
# Epoch 93/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 93: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0481 - val_loss: 0.0327
# Epoch 94/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 94: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0370 - val_loss: 0.0318
# Epoch 95/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0493
# Epoch 95: val_loss did not improve from 0.02960
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0493 - val_loss: 0.0301
# Epoch 96/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0412
# Epoch 96: val_loss improved from 0.02960 to 0.02955, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 579ms/step - loss: 0.0412 - val_loss: 0.0295
# Epoch 97/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 97: val_loss did not improve from 0.02955
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0425 - val_loss: 0.0315
# Epoch 98/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 98: val_loss did not improve from 0.02955
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0334 - val_loss: 0.0307
# Epoch 99/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 99: val_loss did not improve from 0.02955
# 11/11 [==============================] - 2s 230ms/step - loss: 0.0285 - val_loss: 0.0318
# Epoch 100/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 100: val_loss did not improve from 0.02955
# 11/11 [==============================] - 2s 230ms/step - loss: 0.0559 - val_loss: 0.0298
# Epoch 101/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0413
# Epoch 101: val_loss improved from 0.02955 to 0.02921, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 554ms/step - loss: 0.0413 - val_loss: 0.0292
# Epoch 102/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0236
# Epoch 102: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 221ms/step - loss: 0.0236 - val_loss: 0.0312
# Epoch 103/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 103: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0431 - val_loss: 0.0312
# Epoch 104/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 104: val_loss did not improve from 0.02921
# 11/11 [==============================] - 3s 239ms/step - loss: 0.0456 - val_loss: 0.0298
# Epoch 105/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 105: val_loss did not improve from 0.02921
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0364 - val_loss: 0.0310
# Epoch 106/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 106: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0381 - val_loss: 0.0313
# Epoch 107/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0289
# Epoch 107: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0289 - val_loss: 0.0305
# Epoch 108/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 108: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0517 - val_loss: 0.0301
# Epoch 109/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 109: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0365 - val_loss: 0.0318
# Epoch 110/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0409
# Epoch 110: val_loss did not improve from 0.02921
# 11/11 [==============================] - 3s 253ms/step - loss: 0.0409 - val_loss: 0.0299
# Epoch 111/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 111: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 224ms/step - loss: 0.0237 - val_loss: 0.0304
# Epoch 112/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 112: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 224ms/step - loss: 0.0202 - val_loss: 0.0311
# Epoch 113/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 113: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0291 - val_loss: 0.0310
# Epoch 114/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 114: val_loss did not improve from 0.02921
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0259 - val_loss: 0.0308
# Epoch 115/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 115: val_loss did not improve from 0.02921
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0383 - val_loss: 0.0303
# Epoch 116/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 116: val_loss improved from 0.02921 to 0.02886, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 545ms/step - loss: 0.0366 - val_loss: 0.0289
# Epoch 117/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 117: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0383 - val_loss: 0.0297
# Epoch 118/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 118: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0310 - val_loss: 0.0291
# Epoch 119/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 119: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0316 - val_loss: 0.0300
# Epoch 120/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 120: val_loss did not improve from 0.02886
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0322 - val_loss: 0.0324
# Epoch 121/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0372
# Epoch 121: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0372 - val_loss: 0.0307
# Epoch 122/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 122: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0291 - val_loss: 0.0312
# Epoch 123/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0404
# Epoch 123: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0404 - val_loss: 0.0314
# Epoch 124/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0486
# Epoch 124: val_loss did not improve from 0.02886
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0486 - val_loss: 0.0296
# Epoch 125/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 125: val_loss did not improve from 0.02886
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0371 - val_loss: 0.0291
# Epoch 126/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 126: val_loss improved from 0.02886 to 0.02879, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 489ms/step - loss: 0.0444 - val_loss: 0.0288
# Epoch 127/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 127: val_loss improved from 0.02879 to 0.02852, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 484ms/step - loss: 0.0270 - val_loss: 0.0285
# Epoch 128/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0319
# Epoch 128: val_loss did not improve from 0.02852
# 11/11 [==============================] - 3s 290ms/step - loss: 0.0319 - val_loss: 0.0294
# Epoch 129/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 129: val_loss did not improve from 0.02852
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0247 - val_loss: 0.0292
# Epoch 130/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 130: val_loss did not improve from 0.02852
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0387 - val_loss: 0.0299
# Epoch 131/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 131: val_loss did not improve from 0.02852
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0238 - val_loss: 0.0298
# Epoch 132/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 132: val_loss did not improve from 0.02852
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0275 - val_loss: 0.0300
# Epoch 133/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0413
# Epoch 133: val_loss did not improve from 0.02852
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0413 - val_loss: 0.0314
# Epoch 134/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0283
# Epoch 134: val_loss did not improve from 0.02852
# 11/11 [==============================] - 2s 226ms/step - loss: 0.0283 - val_loss: 0.0292
# Epoch 135/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 135: val_loss improved from 0.02852 to 0.02847, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 484ms/step - loss: 0.0381 - val_loss: 0.0285
# Epoch 136/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 136: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0393 - val_loss: 0.0292
# Epoch 137/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0236
# Epoch 137: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 229ms/step - loss: 0.0236 - val_loss: 0.0290
# Epoch 138/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0343
# Epoch 138: val_loss did not improve from 0.02847
# 11/11 [==============================] - 3s 257ms/step - loss: 0.0343 - val_loss: 0.0297
# Epoch 139/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 139: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0265 - val_loss: 0.0311
# Epoch 140/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0321
# Epoch 140: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0321 - val_loss: 0.0317
# Epoch 141/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 141: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0447 - val_loss: 0.0291
# Epoch 142/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 142: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0346 - val_loss: 0.0313
# Epoch 143/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0376
# Epoch 143: val_loss did not improve from 0.02847
# 11/11 [==============================] - 3s 288ms/step - loss: 0.0376 - val_loss: 0.0303
# Epoch 144/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0352
# Epoch 144: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0352 - val_loss: 0.0297
# Epoch 145/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 145: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0310 - val_loss: 0.0285
# Epoch 146/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 146: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0286 - val_loss: 0.0290
# Epoch 147/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 147: val_loss did not improve from 0.02847
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0325 - val_loss: 0.0292
# Epoch 148/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 148: val_loss did not improve from 0.02847
# 11/11 [==============================] - 3s 256ms/step - loss: 0.0270 - val_loss: 0.0299
# Epoch 149/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 149: val_loss did not improve from 0.02847
# 11/11 [==============================] - 3s 242ms/step - loss: 0.0245 - val_loss: 0.0293
# Epoch 150/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 150: val_loss improved from 0.02847 to 0.02801, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0244 - val_loss: 0.0280
# Epoch 151/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0256
# Epoch 151: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0256 - val_loss: 0.0289
# Epoch 152/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 152: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0285 - val_loss: 0.0306
# Epoch 153/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 153: val_loss did not improve from 0.02801
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0267 - val_loss: 0.0296
# Epoch 154/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 154: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0306 - val_loss: 0.0281
# Epoch 155/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 155: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0210 - val_loss: 0.0282
# Epoch 156/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 156: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0239 - val_loss: 0.0294
# Epoch 157/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 157: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0312 - val_loss: 0.0298
# Epoch 158/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 158: val_loss did not improve from 0.02801
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0297 - val_loss: 0.0283
# Epoch 159/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 159: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0322 - val_loss: 0.0282
# Epoch 160/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 160: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0346 - val_loss: 0.0283
# Epoch 161/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 161: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0309 - val_loss: 0.0292
# Epoch 162/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 162: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0246 - val_loss: 0.0299
# Epoch 163/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0330
# Epoch 163: val_loss did not improve from 0.02801
# 11/11 [==============================] - 3s 258ms/step - loss: 0.0330 - val_loss: 0.0284
# Epoch 164/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 164: val_loss did not improve from 0.02801
# 11/11 [==============================] - 3s 231ms/step - loss: 0.0277 - val_loss: 0.0281
# Epoch 165/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0243
# Epoch 165: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0243 - val_loss: 0.0299
# Epoch 166/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 166: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0303 - val_loss: 0.0297
# Epoch 167/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 167: val_loss did not improve from 0.02801
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0235 - val_loss: 0.0289
# Epoch 168/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 168: val_loss improved from 0.02801 to 0.02800, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 563ms/step - loss: 0.0279 - val_loss: 0.0280
# Epoch 169/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 169: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0220 - val_loss: 0.0291
# Epoch 170/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 170: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0241 - val_loss: 0.0299
# Epoch 171/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0328
# Epoch 171: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0328 - val_loss: 0.0298
# Epoch 172/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 172: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0345 - val_loss: 0.0294
# Epoch 173/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 173: val_loss did not improve from 0.02800
# 11/11 [==============================] - 3s 292ms/step - loss: 0.0309 - val_loss: 0.0295
# Epoch 174/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 174: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0276 - val_loss: 0.0289
# Epoch 175/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0264
# Epoch 175: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0264 - val_loss: 0.0294
# Epoch 176/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0260
# Epoch 176: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0260 - val_loss: 0.0296
# Epoch 177/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 177: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0301 - val_loss: 0.0291
# Epoch 178/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 178: val_loss did not improve from 0.02800
# 11/11 [==============================] - 3s 249ms/step - loss: 0.0227 - val_loss: 0.0284
# Epoch 179/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 179: val_loss did not improve from 0.02800
# 11/11 [==============================] - 3s 255ms/step - loss: 0.0280 - val_loss: 0.0298
# Epoch 180/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0258
# Epoch 180: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0258 - val_loss: 0.0293
# Epoch 181/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 181: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 227ms/step - loss: 0.0186 - val_loss: 0.0288
# Epoch 182/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 182: val_loss did not improve from 0.02800
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0179 - val_loss: 0.0282
# Epoch 183/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 183: val_loss improved from 0.02800 to 0.02792, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 557ms/step - loss: 0.0268 - val_loss: 0.0279
# Epoch 184/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 184: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0247 - val_loss: 0.0284
# Epoch 185/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 185: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0285 - val_loss: 0.0294
# Epoch 186/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 186: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0282 - val_loss: 0.0287
# Epoch 187/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 187: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0266 - val_loss: 0.0291
# Epoch 188/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 188: val_loss did not improve from 0.02792
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0294 - val_loss: 0.0283
# Epoch 189/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 189: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0220 - val_loss: 0.0287
# Epoch 190/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 190: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0277 - val_loss: 0.0286
# Epoch 191/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 191: val_loss did not improve from 0.02792
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0334 - val_loss: 0.0285
# Epoch 192/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 192: val_loss improved from 0.02792 to 0.02780, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 514ms/step - loss: 0.0296 - val_loss: 0.0278
# Epoch 193/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 193: val_loss did not improve from 0.02780
# 11/11 [==============================] - 3s 245ms/step - loss: 0.0238 - val_loss: 0.0292
# Epoch 194/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0228
# Epoch 194: val_loss did not improve from 0.02780
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0228 - val_loss: 0.0295
# Epoch 195/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 195: val_loss did not improve from 0.02780
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0231 - val_loss: 0.0283
# Epoch 196/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 196: val_loss did not improve from 0.02780
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0241 - val_loss: 0.0281
# Epoch 197/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 197: val_loss did not improve from 0.02780
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0282 - val_loss: 0.0278
# Epoch 198/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0353
# Epoch 198: val_loss did not improve from 0.02780
# 11/11 [==============================] - 3s 288ms/step - loss: 0.0353 - val_loss: 0.0280
# Epoch 199/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 199: val_loss improved from 0.02780 to 0.02756, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 480ms/step - loss: 0.0291 - val_loss: 0.0276
# Epoch 200/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0255
# Epoch 200: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0255 - val_loss: 0.0279
# Epoch 201/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 201: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0312 - val_loss: 0.0287
# Epoch 202/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0284
# Epoch 202: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0284 - val_loss: 0.0284
# Epoch 203/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 203: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0275 - val_loss: 0.0281
# Epoch 204/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 204: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0272 - val_loss: 0.0280
# Epoch 205/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 205: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0204 - val_loss: 0.0284
# Epoch 206/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0260
# Epoch 206: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0260 - val_loss: 0.0286
# Epoch 207/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 207: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 236ms/step - loss: 0.0292 - val_loss: 0.0278
# Epoch 208/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 208: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0268 - val_loss: 0.0279
# Epoch 209/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0283
# Epoch 209: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0283 - val_loss: 0.0285
# Epoch 210/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0252
# Epoch 210: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0252 - val_loss: 0.0284
# Epoch 211/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 211: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 230ms/step - loss: 0.0170 - val_loss: 0.0280
# Epoch 212/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0229
# Epoch 212: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0229 - val_loss: 0.0281
# Epoch 213/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 213: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0266 - val_loss: 0.0281
# Epoch 214/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 214: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0248 - val_loss: 0.0280
# Epoch 215/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 215: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0203 - val_loss: 0.0277
# Epoch 216/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 216: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0230 - val_loss: 0.0286
# Epoch 217/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 217: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0278 - val_loss: 0.0286
# Epoch 218/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0264
# Epoch 218: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 276ms/step - loss: 0.0264 - val_loss: 0.0286
# Epoch 219/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 219: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0216 - val_loss: 0.0276
# Epoch 220/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0304
# Epoch 220: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0304 - val_loss: 0.0278
# Epoch 221/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 221: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0314 - val_loss: 0.0278
# Epoch 222/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 222: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0274 - val_loss: 0.0280
# Epoch 223/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 223: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0227 - val_loss: 0.0277
# Epoch 224/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 224: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0230 - val_loss: 0.0282
# Epoch 225/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 225: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0226 - val_loss: 0.0302
# Epoch 226/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 226: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0242 - val_loss: 0.0294
# Epoch 227/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0214
# Epoch 227: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0214 - val_loss: 0.0284
# Epoch 228/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 228: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0269 - val_loss: 0.0284
# Epoch 229/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 229: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 299ms/step - loss: 0.0224 - val_loss: 0.0286
# Epoch 230/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 230: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0201 - val_loss: 0.0286
# Epoch 231/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 231: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0269 - val_loss: 0.0279
# Epoch 232/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0254
# Epoch 232: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0254 - val_loss: 0.0285
# Epoch 233/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 233: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0265 - val_loss: 0.0288
# Epoch 234/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 234: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 259ms/step - loss: 0.0265 - val_loss: 0.0289
# Epoch 235/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 235: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0233 - val_loss: 0.0287
# Epoch 236/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 236: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0197 - val_loss: 0.0286
# Epoch 237/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 237: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0278 - val_loss: 0.0280
# Epoch 238/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 238: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0244 - val_loss: 0.0279
# Epoch 239/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 239: val_loss improved from 0.02756 to 0.02756, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 564ms/step - loss: 0.0237 - val_loss: 0.0276
# Epoch 240/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 240: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0217 - val_loss: 0.0278
# Epoch 241/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 241: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0186 - val_loss: 0.0278
# Epoch 242/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 242: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0219 - val_loss: 0.0276
# Epoch 243/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0243
# Epoch 243: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0243 - val_loss: 0.0281
# Epoch 244/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 244: val_loss did not improve from 0.02756
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0272 - val_loss: 0.0288
# Epoch 245/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 245: val_loss did not improve from 0.02756
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0266 - val_loss: 0.0281
# Epoch 246/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 246: val_loss improved from 0.02756 to 0.02753, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 5s 491ms/step - loss: 0.0244 - val_loss: 0.0275
# Epoch 247/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 247: val_loss improved from 0.02753 to 0.02741, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 11/11 [==============================] - 6s 556ms/step - loss: 0.0183 - val_loss: 0.0274
# Epoch 248/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 248: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0217 - val_loss: 0.0276
# Epoch 249/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 249: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0186 - val_loss: 0.0278
# Epoch 250/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 250: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0249 - val_loss: 0.0281
# Epoch 251/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 251: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0168 - val_loss: 0.0279
# Epoch 252/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 252: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 247ms/step - loss: 0.0246 - val_loss: 0.0277
# Epoch 253/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 253: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 255ms/step - loss: 0.0237 - val_loss: 0.0279
# Epoch 254/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 254: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0219 - val_loss: 0.0282
# Epoch 255/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 255: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0219 - val_loss: 0.0277
# Epoch 256/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0222
# Epoch 256: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0222 - val_loss: 0.0279
# Epoch 257/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0232
# Epoch 257: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0232 - val_loss: 0.0285
# Epoch 258/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0256
# Epoch 258: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 310ms/step - loss: 0.0256 - val_loss: 0.0285
# Epoch 259/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 259: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0213 - val_loss: 0.0278
# Epoch 260/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 260: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0231 - val_loss: 0.0280
# Epoch 261/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 261: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0249 - val_loss: 0.0282
# Epoch 262/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 262: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0215 - val_loss: 0.0280
# Epoch 263/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 263: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 232ms/step - loss: 0.0206 - val_loss: 0.0280
# Epoch 264/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 264: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 246ms/step - loss: 0.0244 - val_loss: 0.0287
# Epoch 265/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 265: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0220 - val_loss: 0.0282
# Epoch 266/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 266: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0244 - val_loss: 0.0278
# Epoch 267/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 267: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0211 - val_loss: 0.0279
# Epoch 268/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0281
# Epoch 268: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0281 - val_loss: 0.0285
# Epoch 269/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 269: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 284ms/step - loss: 0.0239 - val_loss: 0.0282
# Epoch 270/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 270: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0224 - val_loss: 0.0283
# Epoch 271/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 271: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0220 - val_loss: 0.0279
# Epoch 272/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 272: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0175 - val_loss: 0.0277
# Epoch 273/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 273: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0197 - val_loss: 0.0277
# Epoch 274/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0229
# Epoch 274: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 247ms/step - loss: 0.0229 - val_loss: 0.0276
# Epoch 275/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0212
# Epoch 275: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 253ms/step - loss: 0.0212 - val_loss: 0.0278
# Epoch 276/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 276: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0205 - val_loss: 0.0278
# Epoch 277/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 277: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0193 - val_loss: 0.0280
# Epoch 278/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 278: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0220 - val_loss: 0.0283
# Epoch 279/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 279: val_loss did not improve from 0.02741
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0223 - val_loss: 0.0279
# Epoch 280/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 280: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 316ms/step - loss: 0.0218 - val_loss: 0.0279
# Epoch 281/400
# 11/11 [==============================] - ETA: 0s - loss: 0.0193Restoring model weights from the end of the best epoch: 211.
#
# Epoch 281: val_loss did not improve from 0.02741
# 11/11 [==============================] - 3s 243ms/step - loss: 0.0193 - val_loss: 0.0292
# Epoch 281: early stopping
# Training time: 0:19:12.322996

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (129359042, 130940883)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.016804145649075508
# Validation loss 0.027407243847846985

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX1.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.2,1.2])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.2,1.2])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 3/3 [==============================] - 14s 656ms/step
# 2/2 [==============================] - 9s 38ms/step

# %%
test_dev = abs(pred_test-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.005238073966059878
# Mean absolute deviation: 0.05903012399718763
# RMS deviation: 0.07237453948772232
# MAPE: 6.407272227386807
